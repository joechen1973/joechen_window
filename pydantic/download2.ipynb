# %%
#可以從json檔案中抓出自己想要的資料
#pydantic是確認資料的安全性,以避免缺資料,或....

import requests
from requests import Response

aqi_url = 'https://data.moenv.gov.tw/api/v2/aqx_p_488?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate desc&format=JSON'

try:
    res:requests = requests.request("GET",aqi_url)
except Exception as e:
    print(e)
# res:requests.Response = requests.request("GET",aqi_url)

if res.ok:
    print("下載成功")
else:
    print("下載失敗")
# Out:
# 下載成功

# %%
# print(res.text)
type(res.text)
# Out:
# str

# %%
try:
    json_data:dict = res.json()
except requests.exceptions.JSONDecodeError:
    print("json格式不正確")
sites:list = json_data["records"]
for site in sites:
    print(site)
# Out:
# {'sitename': '屏東(枋山)', 'county': '屏東縣', 'aqi': '47', 'pollutant': '', 'status': '良好', 'so2': '0.1', 'co': '0.13', 'o3': '48.8', 'o3_8hr': '51.6', 'pm10': '10', 'pm2.5': '0', 'no2': '2', 'nox': '2.2', 'no': '0.2', 'windspeed': '3.3', 'winddirec': '91', 'datacreationdate': '2024-06-04 08:00', 'unit': '', 'co_8hr': '0.1', 'pm2.5_avg': '1.9', 'pm10_avg': '9', 'so2_avg': '0', 'longitude': '120.651472', 'latitude': '22.260899', 'siteid': '313'}
# {'sitename': '大甲（日南國小）', 'county': '臺中市', 'aqi': '23', 'pollutant': '', 'status': '良好', 'so2': '0.2', 'co': '0.47', 'o3': '6.4', 'o3_8hr': '14.5', 'pm10': '27', 'pm2.5': '9', 'no2': '11.5', 'nox': '36.3', 'no': '24.8', 'windspeed': '0.9', 'winddirec': '61', 'datacreationdate': '2024-06-04 08:00', 'unit': '', 'co_8hr': '0.2', 'pm2.5_avg': '7.1', 'pm10_avg': '18', 'so2_avg': '0', 'longitude': '120.65525382', 'latitude': '24.39017512', 'siteid': '312'}
# ...

# %%
for site in sites:
    print(site['sitename'],site['county'],site['aqi'],site['status'])
    print(type(site["aqi"]))
# Out:
# 屏東(枋山) 屏東縣 47 良好
# <class 'str'>
# 大甲（日南國小） 臺中市 23 良好
# <class 'str'>
# 新北(樹林) 新北市 48 良好
# <class 'str'>
# 屏東（琉球） 屏東縣 37 良好
# <class 'str'>
# 臺南（麻豆） 臺南市 62 普通
# <class 'str'>
# 高雄（湖內） 高雄市 74 普通
# <class 'str'>
# 彰化（員林） 彰化縣 67 普通
# <class 'str'>
# 大城 彰化縣 53 普通
# <class 'str'>
# 富貴角 新北市 64 普通
# <class 'str'>
# 麥寮 雲林縣 52 普通
# <class 'str'>
# 關山 臺東縣 25 良好
# <class 'str'>
# 馬公 澎湖縣 74 普通
# <class 'str'>
# 金門 金門縣 35 良好
# <class 'str'>
# 馬祖 連江縣 39 良好
# <class 'str'>
# 埔里 南投縣 55 普通
# <class 'str'>
# 復興 高雄市 42 良好
# <class 'str'>
# 永和 新北市 40 良好
# <class 'str'>
# 竹山 南投縣 63 普通
# <class 'str'>
# 中壢 桃園市 55 普通
# <class 'str'>
# 三重 新北市 60 普通
# <class 'str'>
# 冬山 宜蘭縣 31 良好
# <class 'str'>
# 宜蘭 宜蘭縣 31 良好
# <class 'str'>
# 陽明 臺北市 71 普通
# <class 'str'>
# 花蓮 花蓮縣 22 良好
# <class 'str'>
# 臺東 臺東縣 35 良好
# <class 'str'>
# 恆春 屏東縣 48 良好
# <class 'str'>
# 潮州 屏東縣 31 良好
# <class 'str'>
# 屏東 屏東縣 55 普通
# <class 'str'>
# 小港 高雄市 52 普通
# <class 'str'>
# 前鎮 高雄市 43 良好
# <class 'str'>
# 前金 高雄市 43 良好
# <class 'str'>
# ...
